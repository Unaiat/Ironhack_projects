# %% [markdown]
# ![texto_descriptivo](portada.jpg)

# %% [markdown]
# ### Import the pandas library

# %%
import pandas as pd
import src.limpieza_texto as lt

# %% [markdown]
# ### Open the dataset

# %%
data = pd.read_csv("data/attacks.csv",encoding = "ISO-8859-1")

# %% [markdown]
# ### Start cleaning data

# %%
# Check the amount of rows and columns
data.shape
# Out:
# (25723, 24)

# %%
# Function to delete the NaN columns
lt.drop_nan(data)

# %%
data.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8698            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 8698   ...      NaN                    NaN  NaN          NaN  NaN
# 8699   ...      NaN                    NaN  NaN          NaN  NaN
# 8700   ...      NaN                    NaN  NaN          NaN  NaN
# 8701   ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %%
# Check how many columns and rows are left
data.shape
# Out:
# (8703, 24)

# %%
# There are still 2400 values where the Case Number is 0
data.loc[(data['Case Number'] == '0')]
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6302           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6303           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6304           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6305           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6306           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...          ...  ...   ...  ...     ...  ...      ...      ...  ...  ...
# 8697           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8698           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#       ... Species  Investigator or Source  pdf href formula href  \
# ...

# %%
# Make a variable to store the rows with the case_n0
case_n0 = data[data['Case Number'] == '0'].index

# %%
# Delete the rows with the case number 
data = data.drop(case_n0, axis = 0)

# %%
# Delete the last part row of the dataframe. 
# n would be the amout of rows to delete. 
n = 1
data.drop(data.tail(n).index,inplace=True)

# %%
data.shape
# Out:
# (8702, 24)

# %% [markdown]
# ### Delete columns that do not have useful information

# %%
# Delete the columns that are not useful for the analysis. 
# There is no info about what the values in Unnamed: 22 and Unnamed: 23 mean.
# The pdf, href formula, href are not useful for the analysis. 
# The Case Number. 1 and Case Number.2 show the date of the attack. 
# The original order is the order in which the data was stored and is not relevant for the analysis. 
lt.drop_columns(data)

# %% [markdown]
# ### Export the dataset to a new csv file to start cleaning the rows

# %%
data.to_csv('./Data/data_cleaned.csv', index=False)
